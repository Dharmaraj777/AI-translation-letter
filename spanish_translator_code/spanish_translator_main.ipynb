# %%
from datetime import datetime
import os
from spanish_translator_config_loader import ConfigLoader
from spanish_translator_logger import logger, log_stream
from spanish_translator_oaiclient import OaiClient
from spanish_translator_utils import UtilityFunctions
from pdf_translator import PDFProcessor

def main():
    config_loader = ConfigLoader.get_instance()
    today_date = datetime.now().strftime("%Y-%m-%d")
    log_file_name = f"translation_log_{today_date}.log"
    oai_client = OaiClient()
    pdf_processor = PDFProcessor()
    ulits = UtilityFunctions()
    logger.info("Starting English-Spanish Translation Process.")

    try:
      
      
        file_list = ulits.get_files_to_process()

        if not file_list:
            logger.warning("No files to process.")
            return
        else:
            logger.info(f"Found the following files to process: {file_list}.")
            for file in file_list:
                try:
                    file_len = ulits.get_page_count_from_blob(file)       
                    logger.info(f"Processing file: {file}...with {file_len} pages")
                    
                    extension = os.path.splitext(file)[1]
                    if extension in (".pdf"):
                        print(f"Processing a **PDF** file: **{file}**")
                        pdf_processor.process_pdf(file, oai_client)
                        print('\n______________________________________')
                    elif extension in (".pptx"):
                        print(f"Processing a **PPTX** file: **{file}**")

                        print('\n______________________________________')
                    elif extension in (".docx"):
                        print(f"Processing a **DOCX** file: **{file}**")

                        print('\n______________________________________')
                    
                    else:
                        logger.error(f"This application is not able to process file with extension type: {extension} at this time.")


                except Exception as e:
                    logger.error(f"Error processing file {file}: {str(e)}")
                    continue

    except Exception as e:
        logger.error(f"An error occurred in the main process: {str(e)}")

    logger.info("************* END of Processing File ******************")

    #upload_log_to_blob(log_file_name, config_loader, log_stream.getvalue())

if __name__ == "__main__":
    main()
# Out:
# 2025-12-01 16:47:24,438 - INFO - Starting English-Spanish Translation Process.
# 2025-12-01 16:47:24,739 - INFO - Found the following files to process: ['Employee launch email blast template  BCC WPR.docx', 'IER-1380550 2026 LGFI BCC Wellness Premium Reward Member Brochure FA.pdf', 'The Power of Positivity 3.26.25.pptx'].
# 2025-12-01 16:47:24,841 - INFO - Processing file: Employee launch email blast template  BCC WPR.docx...with 2 pages
# Processing a **DOCX** file: **Employee launch email blast template  BCC WPR.docx**
#
# ______________________________________
# 2025-12-01 16:47:25,510 - INFO - Processing file: IER-1380550 2026 LGFI BCC Wellness Premium Reward Member Brochure FA.pdf...with 4 pages
# Processing a **PDF** file: **IER-1380550 2026 LGFI BCC Wellness Premium Reward Member Brochure FA.pdf**
# Processing page: 1
# 2025-12-01 16:47:27,879 - INFO - Calling GPT-4.1 vision to translate image text...
# 2025-12-01 16:47:34,263 - INFO - [image translation] GPT output (first 120 chars): 'Para uso con Recompensa Premium de Bienestar para Grupos Grandes\n\nTus Recompensas\nVale la pena estar saludable\nGana y ca'
#
# Para uso con Recompensa Premium de Bienestar para Grupos Grandes
#
# Tus Recompensas
# Vale la pena estar saludable
# Gana y canjea puntos por recompensas geniales
#
# Tus Actividades
# Desafío de Carrera
# Gana y comparte logros
#
# Hábitos Saludables
# Gana y comparte logros
#
# Tu Plan de Salud
# Ver todo
#
# Tarjetas de Seguro
#
# Equipo de Atención
#
# Reclamo Reciente
# $240
# Reclamo Médico
# Alice Smith, MD
#
# BlueCare CONNECT | Tus Incentivos Anuales de Bienestar
#
# Blue Cross Blue Shield de Rhode Island
# Processing page: 2
# 2025-12-01 16:47:34,508 - INFO - Calling GPT-4.1 vision to translate image text...
# 2025-12-01 16:47:40,062 - INFO - [image translation] GPT output (first 120 chars): 'Usa BlueCare Connect para el bienestar\n\nYa sea en línea o en la aplicación, todo lo que necesitas está en un solo lugar '
#
# Usa BlueCare Connect para el bienestar
#
# Ya sea en línea o en la aplicación, todo lo que necesitas está en un solo lugar conveniente. Puedes establecer metas, ganar recompensas por registrar y completar actividades saludables, y divertirte mientras avanzas hacia una mejor salud.
#
# Además, puedes:
#
# ✔ Integrar rastreadores de actividad populares (FitBit™, Garmin™, Apple®, Samsung®, Google Fit™, y otros)
# ✔ Registrar actividades autoinformadas (por ejemplo, nutrición y sueño)
# ✔ Hablar con un entrenador de salud o enfermero/a
# ✔ Unirte a desafíos con amigos y compañeros de trabajo
# ✔ Recibir sugerencias personalizadas de salud y bienestar
#
# Recompensas de bienestar
# Los empleados (suscriptores) acumulan el equivalente a $1 en recompensas por cada 20 puntos ganados en BlueCare Connect. Tanto los suscriptores como los cónyuges cubiertos pueden usar sus puntos para participar en sorteos trimestrales en el Centro de Recompensas.
#
# Empleado:
# Gana hasta $300 en recompensas por año del plan. Además, participa en sorteos.
#
# Cónyuge:
# Gana puntos canjeables solo para entradas a sorteos.
#
# Ejemplo de recompensa
#
# | Puntos      | Recompensa |
# |-------------|------------|
# | 200 puntos  | $10        |
# | 500 puntos  | $25        |
# | 1,000 puntos| $50        |
# | 2,000 puntos| $100       |
#
# Sorteos trimestrales
#
# • Los empleados (suscriptores del plan) y cónyuges inscritos pueden canjear puntos por entradas a sorteos.
# • Los premios son tarjetas de regalo electrónicas de $25.
# • Cada entrada cuesta 20 puntos. Puedes participar varias veces.
# • Los ganadores se sortean al final de cada trimestre calendario.
# • Sujeto a términos y condiciones al participar
# Processing page: 3
# 2025-12-01 16:47:40,276 - INFO - Calling GPT-4.1 vision to translate image text...
# 2025-12-01 16:47:45,296 - INFO - [image translation] GPT output (first 120 chars): 'Cómo comenzar con BlueCare Connect\n\n• Registre su cuenta de miembro en bluecareconnectRI.com.\n• Descargue la aplicación '
#
# Cómo comenzar con BlueCare Connect
#
# • Registre su cuenta de miembro en bluecareconnectRI.com.
# • Descargue la aplicación BlueCare Connect para mayor comodidad.
# • Escanee el código QR y siga los pasos para crear su cuenta BlueCare Connect o vaya a bluecareconnectRI.com.
#
# Preguntas frecuentes
#
# ¿Quién puede participar en el programa de bienestar?
# Tanto los empleados (suscriptores del plan) como sus cónyuges pueden participar. Solo los suscriptores del plan pueden ganar el equivalente de hasta $300 por año del plan en tarjetas de regalo. Los cónyuges pueden canjear puntos por entradas a sorteos.
#
# ¿Cómo canjeo mis recompensas?
# Los puntos pueden canjearse por tarjetas de regalo electrónicas en el Centro de Recompensas a medida que se ganan, sujeto a los plazos de procesamiento. Los sorteos pueden ingresarse trimestralmente.
#
# ¿Cuándo se restablecen mis puntos?
# Los puntos se restablecen en la fecha de renovación anual de su plan.
#
# ¿Puedo sincronizar un dispositivo de fitness, aplicación o contador de pasos?
# Sí, BlueCare Connect se sincroniza con los dispositivos y aplicaciones de seguimiento más comúnmente utilizados (FitBit™, Garmin®, Apple®, Samsung®, Google Fit™, y otros).
#
# ¿Dónde puedo aprender más sobre BlueCare Connect?
# Vea videos útiles y encuentre detalles en bcbsri.com/bcc.
#
# ¿Qué hago si aún tengo preguntas?
# Contacte a su empleador o llame al número que aparece en el reverso de su tarjeta de identificación de miembro de BCBSRI.
# Processing page: 4
# 2025-12-01 16:47:45,430 - INFO - Calling GPT-4.1 vision to translate image text...
# 2025-12-01 16:47:48,908 - INFO - [image translation] GPT output (first 120 chars): 'Fitbit es una marca registrada de Fitbit LLC. Garmin es una marca registrada de Garmin Ltd. Apple es una marca registrad'
#
# Fitbit es una marca registrada de Fitbit LLC. Garmin es una marca registrada de Garmin Ltd. Apple es una marca registrada de Apple Inc. Samsung es una marca registrada de Samsung Electronics Co., Ltd. Google Fit es una marca registrada de Google LLC.
#
# 500 Exchange Street · Providence, RI 02903-2699
#
# Blue Cross & Blue Shield of Rhode Island es una licencia independiente de Blue Cross and Blue Shield Association. 10/25 IER-1380550
#
# 4
#
# ______________________________________
# 2025-12-01 16:47:49,098 - INFO - Processing file: The Power of Positivity 3.26.25.pptx...with 1 pages
# Processing a **PPTX** file: **The Power of Positivity 3.26.25.pptx**
#
# ______________________________________
# 2025-12-01 16:47:49,099 - INFO - ************* END of Processing File ******************

# %%
# %pip install  python-pptx
